# %% [markdown]
# <a href="https://colab.research.google.com/github/chrisdrake112/R-Python/blob/main/JoinPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
NHS = pd.read_excel('/content/HSE Report.xlsx')

# %%
AccountNum = pd.read_excel('/content/accountNumbers.xlsx')

# %%
NHS.head()
# Out:
#     Patient                        Model of Device  Serial Number Pediatric  \
# 0  I0000126  CPAP_Dreamstation Auto CPAP GBX500S15  J2145398291AE        No
# 1  I0000164               CPAP_REMSTAR AUTO___RI_A     M000935494        No
# 2  I0000165       CPAP_REMSTAR PLUS_M SERIES__RI_A     M000935485        No
# 3  I0000168  CPAP_Dreamstation Auto CPAP GBX500S15  J21773694BD72        No
# 4  I0000184  CPAP_Dreamstation Auto CPAP GBX500S15  J23169275AD21        No
#
#   Adult Child Bearing Age  Date End User Notified Patient Status  \
# 0   Yes                NO                     NaN     Unresolved
# 1   Yes                NO                     NaN       Resolved
# 2   Yes                NO                     NaN     Unresolved
# 3    No                NO                     NaN       Resolved
# 4   Yes                NO                     NaN       Resolved
#
#   Contract Type Replacement Date                      Replacement Model  \
# ...

# %%
AccountNum.head()
# Out:
#   Account Number Date Of Birth         Address Line 2  \
# 0       I0001650    1947-04-11         3 DRUIDS COURT
# 1       I0003453    2011-06-03                    NaN
# 2       I0003106    1964-04-14  23 ST OLIVER PLUNKETT
# 3       I0004461    1957-12-26                    NaN
# 4       I0007043    1921-01-01                    NaN
#
#             Address Line 3 Address Line 4 Address Line 5
# 0  DRUIDS GLEN GOLF RESORT            NaN       A63 KX70
# 1                      NaN            NaN       A82 AY63
# 2                KENTSTOWN            NaN       A91 H5C2
# 3                      NaN            NaN       H12 HX47
# 4                  Donegal            NaN       F94 V6P3

# %%
NHSAccountNum = pd.merge(NHS,AccountNum,
                  how = 'left',
                  left_on='Patient',
                  right_on='Account Number')

# %%
len(NHSAccountNum)
# Out:
# 5201

# %%
NHSAccountNum.to_excel('NHSAccountNum.xlsx',index = False)
